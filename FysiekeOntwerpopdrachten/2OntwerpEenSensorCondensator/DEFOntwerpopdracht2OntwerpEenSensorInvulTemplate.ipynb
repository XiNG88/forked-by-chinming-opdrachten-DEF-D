# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 2 invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in (als in *PR* op GitHub en de link op Brightspace). Zet jullie groepsnummer, studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.
#
# | Groep: XX     |  |
# | :-------------|:-------------|
# | Tom Vermeulen | 6441637 |
# | Chinming Zhu | 6325971 |
# | Student naam 3| Student Studienummer 3 |
# | Planning Groep: XX     |Tijdstip / Tijdspanne  |
# |---|---|
# | Plaatcondensator maken | 11:45 |
# | Sensoren bedenken om te maken | 12:30 |
# | Sensor gemaakt en gekalibreert | 16:30 |
# | Finishing touches | 17:30 |

# %% [markdown]
# ## *Opdracht 1*: Sanity check 3

# %% [markdown]
# #### Voeg hier een foto van de schets van je plaatcondensator in. Geef daarbij ook duidelijk de waarde van $A$ en $d$ aan.
# <img src="tudelftLogo.png" alt="schets student 1" width="400"/>

# %%
# Schrijf hier een python functie die de capaciteit van een plaatcondensator uitrekent. Zorg dat de functie
# als input de ontwerpparameters van de vlakke plaat formule accepteert (oppervlakte, afstand en diëlektrische
# constante) en als output de capaciteit van de vlakke plaat condensator met die ontwerpparameters.
# Je gaat deze formule de rest van de dag gebruiken: controleer hem goed!
# Run deze cel, pas deze niet aan
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
from IPython.display import Image, display
from scipy.optimize import curve_fit

def vlakkeplaat(A, d, eps_r=3.0, eps0=8.8541878128e-12):
    return eps0 * eps_r * A / (d)

# Optioneel: schrijf je functie zodanig dat je arrays als input kan geven en (dus) ook arrays als output.

# %%
# Gebruik je formule om uit te rekenen wat je verwacht dat de capaciteit van jullie vlakke plaat condensatoren
# gaat zijn.

C = [vlakkeplaat(0.1, 0.0025)] #, vlakkeplaat(4.7),vlakkeplaat(1.2)]

print(C)
#print(f"Berekende capaciteit plaatcondensator groep 55 is {C[0]:.1f} pF")
# Out:
# [1.0625025375360001e-09]

# %% [markdown]
# #### Voeg hier een foto van je plaatcondensator en van de meting op de scope in. Dus 2 foto's.
# ![scope meting 1](Oscilloscoop.jpeg)
# ![scope meting 2](sensor.jpeg)

# %% [markdown]
# ### Meting capaciteit
# Vul onderstaande tabel in. Bij Sanity check 2 heb je afgeleid hoe je van berekende capaciteit naar berekend voltage gaat en terug.
#
#
# | Namen         | Berekende capaciteit   | Berekend Voltage | Gemeten Voltage | Gemeten capaciteit   |
# |-------------|-------------:|-------------:|-------------:|-------------:|
# | groep XX| 3.382 * 10^-10 |1.7 volt| 8 volt|0.9947e-10 F

# %% [markdown]
# ## *Opdracht 2:* Synthese.

# %% [markdown]
# #### Voeg hier voor een foto van je schets(en) van minimaal drie sensoren in.
# ![drie schetsen](Schetsen.jpeg)

# %% [markdown]
# ## Opdracht 3: Welke sensor gaan jullie maken?

# %% [markdown]
# Elektrische telsensor. Een sensor die meet hoeveel van een medium er zijn. In dit geval het aantal papieren blaadjes.

# %% [markdown]
# ## Opdracht 4: Uitgewerkte schets (afmetingen!) en plot van de ontwerpgrafiek.

# %% [markdown]
# #### Voeg hier een foto van jullie uitgewerkte  schets van de sensor die jullie gaan maken in
# ![uitgewerkte schets](schets_condensator.jpeg)
# ![uitgewerkte schets](Schakeling.jpeg)

# %%
def vlakkeplaat(A, d, eps_r=3.0, eps0=8.8541878128e-12):
    """Capaciteit van een vlakke-plaatcondensator in farad."""
    return eps0 * eps_r * A / d

# Gegeven
A = 0.01                 # m^2
d_papier = 0.1e-3        # 0.1 mm = 1e-4 m per vel papier
eps_r = 3.0

# X-schaal: max 50 vellen papier
vellen = np.arange(1, 51)           # 1 t/m 50 vellen
d = vellen * d_papier               # dikte in meter

# Capaciteit in pF
C_F = vlakkeplaat(A, d, eps_r=eps_r)
C_pF = C_F * 1e12

# Plot
plt.figure(figsize=(8, 5))
plt.plot(vellen, C_pF, marker="o", markersize=3)
plt.xlabel("Aantal vellen papier")
plt.ylabel("Capaciteit (pF)")
plt.title("Capaciteit vs. aantal vellen papier")
plt.xlim(0, 50)      # x-range 0 t/m 50 vellen
plt.ylim(0, 500)     # y-range 0 t/m 500 pF
plt.xticks(np.arange(0, 51, 5))
plt.yticks(np.arange(0, 501, 50))
plt.grid(True)
plt.tight_layout()
plt.show()

# waarden binnen de plotrange tonen
print("Waarden binnen 0-500 pF:")
for n, c in zip(vellen, C_pF):
    if 0 <= c <= 500:
        print(f"{n:2d} vellen -> {c:8.2f} pF")
# Out:
# Waarden binnen 0-500 pF:
#  6 vellen ->   442.71 pF
#  7 vellen ->   379.47 pF
#  8 vellen ->   332.03 pF
#  9 vellen ->   295.14 pF
# 10 vellen ->   265.63 pF
# 11 vellen ->   241.48 pF
# 12 vellen ->   221.35 pF
# 13 vellen ->   204.33 pF
# 14 vellen ->   189.73 pF
# 15 vellen ->   177.08 pF
# 16 vellen ->   166.02 pF
# 17 vellen ->   156.25 pF
# 18 vellen ->   147.57 pF
# 19 vellen ->   139.80 pF
# 20 vellen ->   132.81 pF
# 21 vellen ->   126.49 pF
# 22 vellen ->   120.74 pF
# 23 vellen ->   115.49 pF
# 24 vellen ->   110.68 pF
# 25 vellen ->   106.25 pF
# 26 vellen ->   102.16 pF
# 27 vellen ->    98.38 pF
# 28 vellen ->    94.87 pF
# 29 vellen ->    91.60 pF
# 30 vellen ->    88.54 pF
# 31 vellen ->    85.69 pF
# 32 vellen ->    83.01 pF
# 33 vellen ->    80.49 pF
# 34 vellen ->    78.13 pF
# 35 vellen ->    75.89 pF
# 36 vellen ->    73.78 pF
# 37 vellen ->    71.79 pF
# 38 vellen ->    69.90 pF
# 39 vellen ->    68.11 pF
# 40 vellen ->    66.41 pF
# 41 vellen ->    64.79 pF
# ...

# %% [markdown]
# ## Opdracht 5: Invullen tabel LTSpice.

# %% [markdown]
# |         | Capaciteit waarde (pF)  | LTSpice berekend output Vpp (mV)|
# |-------------|-------------:|-------------:|
# | minmale capaciteit| 40 pF |200 mV |
# | gemiddelde capaciteit| 220 pF |1 V |
# | maximale capaciteit| 400 pF |1.6 V |

# %% [markdown]
# ## Opdracht 6: Foto's werkende opstelling.

# %% [markdown]
# #### Voeg hier de foto's van je sensoren in actie in.
# ![meting 1](Opstellingwerkend.jpeg)

# %% [markdown]
# ## Opdracht 7: Plot de kalibratiegrafiek.

# %%
# Plot hier je gemeten kalibratiegrafiek en plot in dezelfde figuur ook je verwachte ontwerpgrafiek.

eps0 = 8.8541878128e-12   # F/m
eps_r = 3.0
A = 0.01                  # m^2
d_papier = 0.1e-3         # m per vel


n = np.array([1, 2, 3, 4, 5, 10, 15, 20, 25, 30, 35], dtype=float)
C_pF = np.array([500, 350, 325, 260, 225, 140, 110, 70, 65, 58, 53], dtype=float)

# 2% onzekerheid
C_err_pF = 0.02 * C_pF


C_uF = C_pF * 1e-6
C_err_uF = C_err_pF * 1e-6


def C_model_uF(n, a, b):
    d = n * d_papier  # meter
    d_fit = (d ** b) + a
    C_F = eps0 * eps_r * A / d_fit
    return C_F * 1e6  # naar microfarad


p0 = [1e-4, 1.0]   # [a, b]

bounds_lower = [0.0, 0.1]
bounds_upper = [1.0, 5.0]

popt, pcov = curve_fit(
    C_model_uF,
    n, C_uF,
    p0=p0,
    sigma=C_err_uF,
    absolute_sigma=True,
    bounds=(bounds_lower, bounds_upper),
    maxfev=20000
)

a_fit, b_fit = popt
a_err, b_err = np.sqrt(np.diag(pcov))

print("Fitresultaat voor C = eps0*eps_r*A / ((d**b)+a)")
print(f"a = {a_fit:.6e} ± {a_err:.2e}  (eenheid: m^b)")
print(f"b = {b_fit:.6f} ± {b_err:.4f}")

C_pred_uF = C_model_uF(n, a_fit, b_fit)
res = C_uF - C_pred_uF


# R^2 (niet perfect voor gewogen niet-lineaire fit, maar handig als indicatie)
ss_res = np.sum((C_uF - C_pred_uF)**2)
ss_tot = np.sum((C_uF - np.mean(C_uF))**2)
r2 = 1 - ss_res / ss_tot


vellen2 = np.arange(1, 51, dtype=float)
C_fit_uF = C_model_uF(vellen2, a_fit, b_fit)
C_fit_pF = C_fit_uF * 1e6  # µF -> pF

plt.figure(figsize=(9, 5.5))

plt.errorbar(
    n, C_pF, yerr=C_err_pF,
    fmt='o', capsize=4, elinewidth=1.2,
    label="Metingen (±2%)"
)

plt.plot(
    vellen2, C_fit_pF, '--', linewidth=2,
    label=(fr"Fit: $C=\frac{{\epsilon_0\epsilon_r A}}{{(d^b)+a}}$" "\n"
           fr"$a={a_fit:.2e}$ (m$^b$), $b={b_fit:.3f}$")
)

plt.xlabel("Aantal vellen papier")
plt.ylabel("Capaciteit (pF)")
plt.title("Niet-lineaire fit op $C=\\epsilon_0\\epsilon_r A/((d^b)+a)$")
plt.xlim(0, 50)
plt.ylim(0, 500)
plt.xticks(np.arange(0, 51, 5))
plt.yticks(np.arange(0, 501, 50))
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Fitresultaat voor C = eps0*eps_r*A / ((d**b)+a)
# a = 3.655435e-04 ± 9.68e-06  (eenheid: m^b)
# b = 0.936488 ± 0.0017

# %% [markdown]
# ## Opdracht 8: Vul de tekst aan.

# %% [markdown]
# Onze sensor kan nog verbetered worden door de volgende verbeteringen (minimaal 2):
#
# * Paperclip heeft geen consistent oppervlak met de plaat, waardoor er meer onzekerheid is.
# * Sensor heeft nog veel invloed van lucht tussen de vellen papier.

# %% [markdown]
# ## Opdracht 9: Uiteindelijke ontwerp en kalibratiegrafiek.

# %% [markdown]
# #### Voeg hier een foto van je uiteindelijke sensor in.
# ![foto sensor](Eindopstelling.jpeg)

# %%
eps0 = 8.8541878128e-12   # F/m
eps_r = 3.0
A = 0.01                  # m^2
d_papier = 0.1e-3         # m per vel

#metingen
n = np.array([1, 2, 3, 4, 5, 10, 15, 20, 25, 30, 35], dtype=float)
C_pF = np.array([500, 350, 325, 260, 225, 140, 110, 70, 65, 58, 53], dtype=float)

# 2% onzekerheid
C_err_pF = 0.02 * C_pF

# pF -> microfarad
# 1 pF = 1e-12 F = 1e-6 µF
C_uF = C_pF * 1e-6
C_err_uF = C_err_pF * 1e-6

def C_model_uF(n, a, b):
    d = n * d_papier  # meter
    d_fit = (d ** b) + a
    C_F = eps0 * eps_r * A / d_fit
    return C_F * 1e6  # naar microfarad

# Theoretisch model (output in microfarad)
# C = eps0 * eps_r * A / d, met d = n * d_papier
def C_theorie_uF(n):
    d = n * d_papier
    C_F = eps0 * eps_r * A / d
    return C_F * 1e6  # naar microfarad

# Fit met curve_fit
# Beginwaarden (belangrijk voor niet-lineaire fit)
# a heeft eenheid m^b (want het wordt opgeteld bij d^b)
p0 = [1e-4, 1.0]   # [a, b]

# Bounds:
# - b positief houden
# - a positief houden voor stabiliteit (anders kan noemer nul/negatief worden)
bounds_lower = [0.0, 0.1]
bounds_upper = [1.0, 5.0]

popt, pcov = curve_fit(
    C_model_uF,
    n, C_uF,
    p0=p0,
    sigma=C_err_uF,
    absolute_sigma=True,
    bounds=(bounds_lower, bounds_upper),
    maxfev=20000
)

a_fit, b_fit = popt
a_err, b_err = np.sqrt(np.diag(pcov))

print("Fitresultaat voor C = eps0*eps_r*A / ((d**b)+a)")
print(f"a = {a_fit:.6e} ± {a_err:.2e}  (eenheid: m^b)")
print(f"b = {b_fit:.6f} ± {b_err:.4f}")

# Fitkwaliteit (op meetpunten)
C_pred_uF = C_model_uF(n, a_fit, b_fit)
res = C_uF - C_pred_uF

# R^2 (niet perfect voor gewogen niet-lineaire fit, maar handig als indicatie)
ss_res = np.sum((C_uF - C_pred_uF) ** 2)
ss_tot = np.sum((C_uF - np.mean(C_uF)) ** 2)
r2 = 1 - ss_res / ss_tot
print(f"R^2 = {r2:.4f}")

# Plot (in pF voor herkenbare schaal)
vellenfinal = np.arange(1, 51, dtype=float)

# Fitlijn
C_fit_uF = C_model_uF(vellenfinal, a_fit, b_fit)
C_fit_pF = C_fit_uF * 1e6  # µF -> pF

# Theoretische lijn
C_theorie_plot_uF = C_theorie_uF(vellenfinal)
C_theorie_plot_pF = C_theorie_plot_uF * 1e6  # µF -> pF

plt.figure(figsize=(9, 5.5))

plt.errorbar(
    n, C_pF, yerr=C_err_pF,
    fmt='o', capsize=4, elinewidth=1.2,
    label="Metingen (±2%)"
)

plt.plot(
    vellenfinal, C_fit_pF, '--', linewidth=2,
    label=(fr"Fit: $C=\frac{{\epsilon_0\epsilon_r A}}{{(d^b)+a}}$" "\n"
           fr"$a={a_fit:.2e}$ (m$^b$), $b={b_fit:.3f}$")
)

# Toegevoegde theoretische plotlijn
plt.plot(
    vellenfinal, C_theorie_plot_pF, '-', linewidth=2,
    label=r"Theorie: $C=\frac{\epsilon_0\epsilon_r A}{d}$ met $d=n\,d_{papier}$"
)

plt.xlabel("Aantal vellen papier")
plt.ylabel("Capaciteit (pF)")
plt.title("capaciteit tegen aantal vellen met metingen/fit en theoretische verwachting")
plt.xlim(0, 50)
plt.ylim(0, 500)
plt.xticks(np.arange(0, 51, 5))
plt.yticks(np.arange(0, 501, 50))
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Fitresultaat voor C = eps0*eps_r*A / ((d**b)+a)
# a = 3.655435e-04 ± 9.68e-06  (eenheid: m^b)
# b = 0.936488 ± 0.0017
# R^2 = 0.9940

# %% [markdown]
# ## Opdracht 10: Vul hieronder de conclusie in.

# %% [markdown]
# De sensor kan goed de verschillen tussen de hoeveelheid vellen meten. Dit geldt wel alleen voor lagere waarden. Vanaf de 20 vellen daalt het verschil in capaciteit heel langzaam. De sensor is dus geschikt voor kleinere hoeveelheden.

# %% [markdown]
# ## Opdracht 11: Kopieer hieronder de leerdoelen.
# 1. Het kunnen gebruiken van de eigenschappen van een elektrische component in een ontwerpproces om een fysische grootheid te meten.
# 2. Kennis hebben van gedrag van elektrische componenten en meetopstellingen.
# 3. Onderdelen van een datasheet zoals een kalibratiegrafiek opstellen, gevoeligheid en onzekerheid beschrijven.

# %% [markdown]
# ### kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 1 beheersen.

# %% [markdown]
# #### Voeg hier een foto van je plaatcondensator en van de meting op de scope in. Dus 2 foto's.
# ![scope meting 1](Oscilloscoop.jpeg)
# ![scope meting 2](sensor.jpeg)

# %%
def vlakkeplaat(A, d, eps_r=3.0, eps0=8.8541878128e-12):
    """Capaciteit van een vlakke-plaatcondensator in farad."""
    return eps0 * eps_r * A / d

# Gegeven
A = 0.01                 # m^2
d_papier = 0.1e-3        # 0.1 mm = 1e-4 m per vel papier
eps_r = 3.0

# X-schaal: max 50 vellen papier
vellen = np.arange(1, 51)           # 1 t/m 50 vellen
d = vellen * d_papier               # dikte in meter

# Capaciteit in pF
C_F = vlakkeplaat(A, d, eps_r=eps_r)
C_pF = C_F * 1e12

# Plot
plt.figure(figsize=(8, 5))
plt.plot(vellen, C_pF, marker="o", markersize=3)
plt.xlabel("Aantal vellen papier")
plt.ylabel("Capaciteit (pF)")
plt.title("Capaciteit vs. aantal vellen papier")
plt.xlim(0, 50)      # x-range 0 t/m 50 vellen
plt.ylim(0, 500)     # y-range 0 t/m 500 pF
plt.xticks(np.arange(0, 51, 5))
plt.yticks(np.arange(0, 501, 50))
plt.grid(True)
plt.tight_layout()
plt.show()

# waarden binnen de plotrange tonen
print("Waarden binnen 0-500 pF:")
for n, c in zip(vellen, C_pF):
    if 0 <= c <= 500:
        print(f"{n:2d} vellen -> {c:8.2f} pF")
# Out:
# Waarden binnen 0-500 pF:
#  6 vellen ->   442.71 pF
#  7 vellen ->   379.47 pF
#  8 vellen ->   332.03 pF
#  9 vellen ->   295.14 pF
# 10 vellen ->   265.63 pF
# 11 vellen ->   241.48 pF
# 12 vellen ->   221.35 pF
# 13 vellen ->   204.33 pF
# 14 vellen ->   189.73 pF
# 15 vellen ->   177.08 pF
# 16 vellen ->   166.02 pF
# 17 vellen ->   156.25 pF
# 18 vellen ->   147.57 pF
# 19 vellen ->   139.80 pF
# 20 vellen ->   132.81 pF
# 21 vellen ->   126.49 pF
# 22 vellen ->   120.74 pF
# 23 vellen ->   115.49 pF
# 24 vellen ->   110.68 pF
# 25 vellen ->   106.25 pF
# 26 vellen ->   102.16 pF
# 27 vellen ->    98.38 pF
# 28 vellen ->    94.87 pF
# 29 vellen ->    91.60 pF
# 30 vellen ->    88.54 pF
# 31 vellen ->    85.69 pF
# 32 vellen ->    83.01 pF
# 33 vellen ->    80.49 pF
# 34 vellen ->    78.13 pF
# 35 vellen ->    75.89 pF
# 36 vellen ->    73.78 pF
# 37 vellen ->    71.79 pF
# 38 vellen ->    69.90 pF
# 39 vellen ->    68.11 pF
# 40 vellen ->    66.41 pF
# 41 vellen ->    64.79 pF
# ...

# %% [markdown]
# ### kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 2 beheersen.

# %% [markdown]
# |         | Capaciteit waarde (pF)  | LTSpice berekend output Vpp (mV)|
# |-------------|-------------:|-------------:|
# | minmale capaciteit| 40 pF |200 mV |
# | gemiddelde capaciteit| 220 pF |1 V |
# | maximale capaciteit| 400 pF |1.6 V |

# %% [markdown]
# #### Voeg hier een foto van jullie uitgewerkte  schets van de sensor die jullie gaan maken in
# ![uitgewerkte schets](schets_condensator.jpeg)
# ![uitgewerkte schets](Schakeling.jpeg)

# %% [markdown]
# ### kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 3 beheersen.

# %% [markdown]
# De sensor kan goed de verschillen tussen de hoeveelheid vellen meten. Dit geldt wel alleen voor lagere waarden. Vanaf de 20 vellen daalt het verschil in capaciteit heel langzaam. De sensor is dus geschikt voor kleinere hoeveelheden.

# %%
eps0 = 8.8541878128e-12   # F/m
eps_r = 3.0
A = 0.01                  # m^2
d_papier = 0.1e-3         # m per vel

#metingen
n = np.array([1, 2, 3, 4, 5, 10, 15, 20, 25, 30, 35], dtype=float)
C_pF = np.array([500, 350, 325, 260, 225, 140, 110, 70, 65, 58, 53], dtype=float)

# 2% onzekerheid
C_err_pF = 0.02 * C_pF

# pF -> microfarad
# 1 pF = 1e-12 F = 1e-6 µF
C_uF = C_pF * 1e-6
C_err_uF = C_err_pF * 1e-6

def C_model_uF(n, a, b):
    d = n * d_papier  # meter
    d_fit = (d ** b) + a
    C_F = eps0 * eps_r * A / d_fit
    return C_F * 1e6  # naar microfarad

# Theoretisch model (output in microfarad)
# C = eps0 * eps_r * A / d, met d = n * d_papier
def C_theorie_uF(n):
    d = n * d_papier
    C_F = eps0 * eps_r * A / d
    return C_F * 1e6  # naar microfarad

# Fit met curve_fit
# Beginwaarden (belangrijk voor niet-lineaire fit)
# a heeft eenheid m^b (want het wordt opgeteld bij d^b)
p0 = [1e-4, 1.0]   # [a, b]

# Bounds:
# - b positief houden
# - a positief houden voor stabiliteit (anders kan noemer nul/negatief worden)
bounds_lower = [0.0, 0.1]
bounds_upper = [1.0, 5.0]

popt, pcov = curve_fit(
    C_model_uF,
    n, C_uF,
    p0=p0,
    sigma=C_err_uF,
    absolute_sigma=True,
    bounds=(bounds_lower, bounds_upper),
    maxfev=20000
)

a_fit, b_fit = popt
a_err, b_err = np.sqrt(np.diag(pcov))

print("Fitresultaat voor C = eps0*eps_r*A / ((d**b)+a)")
print(f"a = {a_fit:.6e} ± {a_err:.2e}  (eenheid: m^b)")
print(f"b = {b_fit:.6f} ± {b_err:.4f}")

# Fitkwaliteit (op meetpunten)
C_pred_uF = C_model_uF(n, a_fit, b_fit)
res = C_uF - C_pred_uF

# R^2 (niet perfect voor gewogen niet-lineaire fit, maar handig als indicatie)
ss_res = np.sum((C_uF - C_pred_uF) ** 2)
ss_tot = np.sum((C_uF - np.mean(C_uF)) ** 2)
r2 = 1 - ss_res / ss_tot
print(f"R^2 = {r2:.4f}")

# Plot (in pF voor herkenbare schaal)
vellenfinal = np.arange(1, 51, dtype=float)

# Fitlijn
C_fit_uF = C_model_uF(vellenfinal, a_fit, b_fit)
C_fit_pF = C_fit_uF * 1e6  # µF -> pF

# Theoretische lijn
C_theorie_plot_uF = C_theorie_uF(vellenfinal)
C_theorie_plot_pF = C_theorie_plot_uF * 1e6  # µF -> pF

plt.figure(figsize=(9, 5.5))

plt.errorbar(
    n, C_pF, yerr=C_err_pF,
    fmt='o', capsize=4, elinewidth=1.2,
    label="Metingen (±2%)"
)

plt.plot(
    vellenfinal, C_fit_pF, '--', linewidth=2,
    label=(fr"Fit: $C=\frac{{\epsilon_0\epsilon_r A}}{{(d^b)+a}}$" "\n"
           fr"$a={a_fit:.2e}$ (m$^b$), $b={b_fit:.3f}$")
)

# Toegevoegde theoretische plotlijn
plt.plot(
    vellenfinal, C_theorie_plot_pF, '-', linewidth=2,
    label=r"Theorie: $C=\frac{\epsilon_0\epsilon_r A}{d}$ met $d=n\,d_{papier}$"
)

plt.xlabel("Aantal vellen papier")
plt.ylabel("Capaciteit (pF)")
plt.title("capaciteit tegen aantal vellen met metingen/fit en theoretische verwachting")
plt.xlim(0, 50)
plt.ylim(0, 500)
plt.xticks(np.arange(0, 51, 5))
plt.yticks(np.arange(0, 501, 50))
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Fitresultaat voor C = eps0*eps_r*A / ((d**b)+a)
# a = 3.655435e-04 ± 9.68e-06  (eenheid: m^b)
# b = 0.936488 ± 0.0017
# R^2 = 0.9940
